# %% [markdown]
# # Revarie LM v1.0 – Colab Fallback Training
# This notebook serves as a fallback when Kaggle quota is exhausted.

# %%
# !pip install -q transformers peft huggingface_hub
print("✅ Fallback ready")
